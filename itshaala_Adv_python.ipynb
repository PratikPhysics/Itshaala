# %%
# functtion

# %%
a = [4,5,5,6,6,5]

dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# print() , len(),type(), dir(),

# %%
def hello(n):
  return f"hello {n}"

# %%
message = hello("swagat")

# %%
message
# Out:
# 'hello swagat'

# %%
def f(x):
  return x**2 + 2

# %%
f(7)
# Out:
# 51

# %%
# two inputs and one output

def बेरीज(a,b):
  return a+b,a*b

# %%
बेरीज(7,3)
# Out:
# (10, 21)

# %%
# age > 50 ---> 80%
# age < 50 ---> 20%

#name,age ----> f(x) ----> name will tell the discount

# %%
def discount(name,age):
  if age > 50 :
    print(f"{name} tumhala 80% discount aahe")
  else:
     print(f"{name} tumhala 20% discount aahe")

# %%
discount("Sagar",68)
# Out:
# Sagar tumhala 80% discount aahe

# %%
# order - --> name,veg? ---> f(x) ---> pneer or chicken?

# %%
# default parameter
def खाणे(name,veg = True):
  if veg :
    print(f" {name} tu paneer खाणे")
  else:
    print(f" {name} tu chicken biriyani")

# %%
खाणे("Amar",False) #veg = "Veg Pulav"
# Out:
#  Amar tu chicken biriyani

# %%
#use the idea of dafault parameter here
#Create a similar function for default "normal" and "sweet" food
#if name given ----> give sandwitch
#if name and asked for sweet ---> give jelebi

# %%
# take a minute , and we'll build it together


def food(name,sweet = False):
  if sweet:
    print(f"{name} tu jelebi kha🍦")

  else:
    print(f"{name} tu sandwitch kha")

# %%
food("Sahil","Sandwich")
# Out:
# Sahil tu jelebi kha🍦

# %%
# function

#fixed deposit
#6%

# 300000 two year on 6% interest ---> 337000

# %%
300000 * 1.06
# Out:
# 318000.0

# %%
318000.0* 1.06
# Out:
# 337080.0

# %%
#  amount,interest,n_year -----> f(x) -----> total amount

# %%
8/100
# Out:
# 0.08

# %%
500000*0.08
# Out:
# 40000.0

# %%
#amount ---> 500000
# interest ---> 8%
# years = 2
# what amount after 2 years?

# %%
amount = 500000
interest = 8
n_year = 2

# %%
#
amount = amount + (amount * (interest/100) )

# %%
amount
# Out:
# 583200.0

# %%
amount = 500000
interest = 8
n_year = 10


for i in range(n_year):
  amount = amount + (amount * (interest/100) )

print(f" the total amount after {n_year}  is {amount}")
# Out:
#  the total amount after 10  is 1079462.4986363933

# %%
amount
# Out:
# 583200.0
